# %%
pip install importlib
# Out:
# Collecting importlib
#   Downloading importlib-1.0.4.zip (7.1 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: importlib
#   Building wheel for importlib (pyproject.toml) ... done
#   Created wheel for importlib: filename=importlib-1.0.4-py3-none-any.whl size=5849 sha256=8d7e32520d796594879d794c6cda94b0386eb38b06811c12f38bed4b81bf4707
#   Stored in directory: /Users/ashmitchhoker/Library/Caches/pip/wheels/40/41/c4/d925a53b7b7e75a65369e1b17f7bade00d7907ac5a7d74dc5f
# Successfully built importlib
# Installing collected packages: importlib
# Successfully installed importlib-1.0.4
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pdb
import src
import glob
import importlib
import os
import cv2

# %%
path = 'Images{}*'.format(os.sep)  # Use os.sep, Windows, linux have different path delimiters
###
print(path)
all_submissions = glob.glob('./src/*')
os.makedirs('./results/', exist_ok=True)
for idx,algo in enumerate(all_submissions):
    print('****************\tRunning Awesome Stitcher developed by: {}  | {} of {}\t********************'.format(algo.split(os.sep)[-1],idx,len(all_submissions)))
    try:
        module_name = '{}_{}'.format(algo.split(os.sep)[-1],'stitcher')
        filepath = '{}{}stitcher.py'.format( algo,os.sep,'stitcher.py')
        spec = importlib.util.spec_from_file_location(module_name, filepath)
        module = importlib.util.module_from_spec(spec)
        spec.loader.exec_module(module)
        PanaromaStitcher = getattr(module, 'PanaromaStitcher')
        inst = PanaromaStitcher()

        ###
        for impaths in glob.glob(path):
            print('\t\t Processing... {}'.format(impaths))
            stitched_image, homography_matrix_list = inst.make_panaroma_for_images_in(path=impaths)

            outfile =  './results/{}/{}.png'.format(impaths.split(os.sep)[-1],spec.name)
            os.makedirs(os.path.dirname(outfile),exist_ok=True)
            cv2.imwrite(outfile,stitched_image)
            print(homography_matrix_list)
            print('Panaroma saved ... @ ./results/{}.png'.format(spec.name))
            print('\n\n')

    except Exception as e:
        print('Oh No! My implementation encountered this issue\n\t{}'.format(e))
        print('\n\n')
# Out:
# Images/*
# ****************	Running Awesome Stitcher developed by: mysticher  | 0 of 4	********************
# 		 Processing... Images/I6
# [array([[ 1.00623456e+00, -4.30773510e-02, -3.86795522e+02],
#        [-1.79275335e-02,  1.00165045e+00,  3.45388989e+01],
#        [ 3.61169642e-06, -5.10972445e-05,  9.98242591e-01]]), array([[ 1.00389267e+00,  6.35452722e-04, -1.98312718e+02],
#        [-8.12767212e-03,  1.01128767e+00, -8.71242146e+00],
#        [-9.48855986e-06,  3.02904459e-05,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 9.24962900e-01, -8.03726663e-02, -9.42825299e+01],
#        [-1.25983636e-03,  8.43799479e-01,  1.27713080e+02],
#        [ 2.92237344e-05, -3.03768797e-04,  9.51468607e-01]]), array([[ 8.73181416e-01,  1.16668159e-01, -3.87412493e+02],
#        [-1.31327167e-01,  7.76679300e-01,  2.47522235e+02],
#        [-2.49354835e-05, -3.63021630e-04,  9.63102996e-01]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# 		 Processing... Images/I1
# [array([[ 7.03297119e-01, -6.21856026e-02, -3.12729484e+03],
#        [-2.16783826e-01,  5.37589180e-01,  8.39523133e+02],
#        [-2.00214071e-04,  2.98492857e-06,  1.29700832e+00]]), array([[ 7.22643335e-01, -8.06514499e-02, -2.28881110e+03],
#        [-1.37469715e-01,  6.83561833e-01,  3.89368577e+02],
#        [-1.36988170e-04, -5.36405065e-06,  1.09684348e+00]]), array([[ 7.73212351e-01, -2.65026774e-02, -1.29581296e+03],
#        [-9.23826615e-02,  8.28940458e-01,  2.02439217e+02],
#        [-7.89488546e-05, -7.50020094e-09,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 1.39140802e+00, -1.64176164e-03,  1.41627539e+03],
#        [ 1.37492771e-01,  1.18808380e+00, -8.12077210e+01],
#        [ 9.01719210e-05,  7.21310145e-06,  1.09042117e+00]]), array([[ 2.30220668e+00,  1.42482109e-02,  4.25476322e+03],
#        [ 3.60486492e-01,  1.46309101e+00, -1.60685987e+01],
#        [ 2.69414371e-04,  2.67083511e-06,  1.42432299e+00]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# 		 Processing... Images/I4
# [array([[ 3.18678942e-01, -2.61339781e-02, -4.83908025e+02],
#        [-5.16222746e-02,  3.92243703e-01,  2.98476034e+02],
#        [-5.26598527e-05,  2.58793297e-07,  1.05732465e+00]]), array([[ 1.06182830e+00, -3.13914695e-02, -5.99190528e+02],
#        [ 4.82601475e-02,  1.05902016e+00, -4.01834751e-01],
#        [ 4.94834578e-05,  9.68466650e-06,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 9.13208796e-01,  2.17433816e-02,  4.92243727e+02],
#        [-4.24934904e-02,  9.48096871e-01,  3.31764303e+01],
#        [-3.22075302e-05, -8.81456574e-06,  9.82163760e-01]]), array([[ 8.26639539e-01,  1.04904887e-02,  1.13281374e+03],
#        [-5.66476241e-02,  9.16924810e-01,  2.01576017e+01],
#        [-5.73331028e-05, -6.09670366e-06,  9.48055674e-01]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# 		 Processing... Images/I3
# [array([[ 1.35288965e+00, -4.84571474e-02, -1.43375440e+03],
#        [ 2.06235509e-03,  1.63038741e+00, -5.65867169e+01],
#        [ 7.64271910e-04,  2.63047937e-04,  9.14213769e-01]]), array([[ 1.52603782e+00, -2.12838030e-02, -9.08467771e+02],
#        [ 2.98706297e-02,  1.54464918e+00, -9.20165963e+01],
#        [ 6.26034299e-04,  1.92299813e-04,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 8.12283047e-01, -4.62721459e-02,  3.24007576e+02],
#        [ 1.57687457e-02,  8.95891703e-01,  7.26399743e-01],
#        [-1.57402626e-04, -4.21244113e-05,  9.37531402e-01]]), array([[ 6.37228364e-01, -1.04265050e-01,  5.38783738e+02],
#        [ 3.11309232e-02,  8.14899905e-01,  1.10143064e+01],
#        [-2.74292241e-04, -3.27207043e-05,  8.38881407e-01]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# 		 Processing... Images/I2
# [array([[ 1.18433181e+00, -3.65705220e-02, -7.82880120e+02],
#        [ 8.94758965e-02,  1.18836313e+00, -6.77249054e+01],
#        [ 3.36368597e-04,  5.50406219e-05,  9.38744812e-01]]), array([[ 1.10458769e+00, -2.35883243e-02, -3.69693265e+02],
#        [ 3.95922285e-02,  1.06716048e+00, -1.01769059e+01],
#        [ 1.52743223e-04, -1.12817160e-05,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 8.52099576e-01, -2.21080773e-03,  3.18707412e+02],
#        [-1.83408825e-02,  9.18150785e-01,  1.33685084e+01],
#        [-1.38033676e-04, -3.87842943e-06,  9.48278470e-01]]), array([[ 6.51249307e-01,  7.05490298e-02,  5.56676856e+02],
#        [-7.25917636e-02,  8.46294601e-01,  1.49465503e+00],
#        [-2.82946642e-04,  4.28524049e-05,  8.29053719e-01]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# 		 Processing... Images/I5
# [array([[ 1.17888920e+00,  1.05425436e-01, -1.08909467e+03],
#        [-4.03923877e-02,  1.10523872e+00,  3.37168119e+01],
#        [ 8.12359925e-05,  1.85835748e-05,  9.80449229e-01]]), array([[ 1.10603261e+00,  5.00477217e-02, -5.40207297e+02],
#        [-9.22288305e-03,  1.06922947e+00, -4.31497207e+01],
#        [ 4.11435196e-05,  1.74686494e-05,  1.00000000e+00]]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]), array([[ 9.43101658e-01, -4.99835138e-02,  4.02515047e+02],
#        [ 1.85459930e-02,  9.53718391e-01,  5.46944469e+01],
#        [-1.97784191e-05, -1.86349314e-05,  9.90594138e-01]]), array([[ 8.56132989e-01, -9.33703134e-02,  9.32084458e+02],
#        [ 8.21833333e-03,  8.97954802e-01,  1.12464313e+02],
#        [-4.72002811e-05, -3.12053662e-05,  9.58947454e-01]])]
# Panaroma saved ... @ ./results/mysticher_stitcher.png
#
#
#
# ****************	Running Awesome Stitcher developed by: DarthVader  | 1 of 4	********************
# 		 Processing... Images/I6
# Found 5 Images for stitching
# Oh No! My implementation encountered this issue
# 	I am an Error. Fix Me Please!
#
#
#
# ****************	Running Awesome Stitcher developed by: JaneDoe  | 2 of 4	********************
# 		 Processing... Images/I6
# Found 5 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# 		 Processing... Images/I1
# Found 6 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# 		 Processing... Images/I4
# Found 5 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# 		 Processing... Images/I3
# Found 5 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# 		 Processing... Images/I2
# Found 5 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# 		 Processing... Images/I5
# Found 5 Images for stitching
# Hii From Jane Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JaneDoe_stitcher.png
#
#
#
# ****************	Running Awesome Stitcher developed by: JohnDoe  | 3 of 4	********************
# 		 Processing... Images/I6
# Found 5 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
#
#
#
# 		 Processing... Images/I1
# Found 6 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
#
#
#
# 		 Processing... Images/I4
# Found 5 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
#
#
#
# 		 Processing... Images/I3
# Found 5 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
#
#
#
# 		 Processing... Images/I2
# Found 5 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
#
#
#
# 		 Processing... Images/I5
# Found 5 Images for stitching
# Hii From John Doe..
# Hey Class, don't worry, I've got your back. Just call me anytime you need help… just not too many times, I'm on a tight loop
# Seems the codebase is going to be organized!
# []
# Panaroma saved ... @ ./results/JohnDoe_stitcher.png
